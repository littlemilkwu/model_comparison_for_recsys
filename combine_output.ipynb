# %%
import numpy as np
import pandas as pd
from config import *

# %%
df_cf_result = pd.read_csv('output/CF_MF_result.csv')
df_cf_result.groupby(by=['model', 'data'])[['RMSE', 'Recall', 'NDCG']].agg(['mean']).round(4)
# Out:
#                    RMSE  Recall    NDCG
#                    mean    mean    mean
# model data
# ICF_p douban     0.7199  0.7281  0.9596
#       movie_len  0.9421  0.5538  0.9172
#       yelp       1.1387  0.6376  0.9608
# ICF_s douban     0.7069  0.7409  0.9610
#       movie_len  0.9443  0.5428  0.9165
#       yelp       1.0844  0.6480  0.9633
# NMF   douban     1.0969  0.7799  0.9439
#       movie_len  1.3016  0.6796  0.9010
#       yelp       1.3227  0.7856  0.9599
# UCF_p douban     0.7244  0.7285  0.9593
#       movie_len  0.9514  0.5221  0.9142
#       yelp       1.1351  0.6188  0.9568
# UCF_s douban     0.7133  0.7336  0.9603
#       movie_len  0.9564  0.5064  0.9141
#       yelp       1.0823  0.6385  0.9622

# %%
df_fm_result = pd.read_csv('output/FM_result.csv')
df_fm_result.groupby(by=['model', 'data'])[['Recall', 'NDCG']].agg(['mean']).round(4)
# Out:
#                    Recall    NDCG
#                      mean    mean
# model  data
# fm     douban      0.4348  0.9296
#        movie_lens  0.5185  0.8563
#        yelp        0.0000  0.9421
# fm_bpr douban      0.0000  0.9363
#        movie_lens  0.0000  0.8577
#        yelp        0.0000  0.9448
# mf_bpr douban      0.0000  0.9361
#        movie_lens  0.0000  0.8934
#        yelp        0.0000  0.9503

# %%
df_nn_result = pd.read_csv('output/NN_result.csv')
df_nn_result.groupby(by=['model', 'data'])[['RMSE', 'Recall', 'NDCG']].agg(['mean']).round(4)
# Out:
#                       RMSE  Recall    NDCG
#                       mean    mean    mean
# model   data
# AFM     douban      0.6974  0.7578  0.9624
#         movie_lens  0.9402  0.5324  0.9124
#         yelp        1.0409  0.6705  0.9650
# CCPM    douban      0.6992  0.7527  0.9619
#         movie_lens  0.9421  0.5452  0.9127
#         yelp        1.0362  0.6796  0.9647
# DC      douban      0.6959  0.7540  0.9619
#         movie_lens  0.9308  0.5496  0.9154
#         yelp        1.0356  0.6847  0.9647
# FNN     douban      0.6952  0.7563  0.9622
#         movie_lens  0.9322  0.5481  0.9150
#         yelp        1.0369  0.7010  0.9648
# IPNN    douban      0.6937  0.7537  0.9624
#         movie_lens  0.9334  0.5508  0.9143
#         yelp        1.0397  0.7034  0.9647
# NFM     douban      0.6968  0.7568  0.9619
#         movie_lens  0.9336  0.5592  0.9154
#         yelp        1.0410  0.7047  0.9649
# OPNN    douban      0.6941  0.7563  0.9623
# ...
